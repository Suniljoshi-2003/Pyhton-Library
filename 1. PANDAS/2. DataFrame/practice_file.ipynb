# %%
#  module import
import pandas as pd

# %% [markdown]
#  # file loding format
# pd.read_csv/excel/json(data.csv/xlsx/json)
# #     x = pd.read_csv("C:\dowanlode\data.csv")

# %% [markdown]
# * Error -->
#
#      * Error ---> UnicodeescapeError
#
#        \ ---> \\
#      * '' and "" --> code not
#       pd.read_csv/excel(r"a\d\data.csv/excel")

# %%
import  pandas as pd

# %%
#  data loding
nfx = pd.read_csv("C:\\Users\\lenovo\\ADVANCE PYTHON (Ravi sir)\\netflix1.csv")

# %%
nfx
# print(nfx.to_string())
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
# check the data type
print(type(nfx))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
nfx.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
#  Atteributes --->
nfx.values
# Out:
# array([['s1', 'Movie', 'Dick Johnson Is Dead', ..., 'PG-13', '90 min',
#         'Documentaries'],
#        ['s3', 'TV Show', 'Ganglands', ..., 'TV-MA', '1 Season',
#         'Crime TV Shows, International TV Shows, TV Action & Adventure'],
#        ['s6', 'TV Show', 'Midnight Mass', ..., 'TV-MA', '1 Season',
#         'TV Dramas, TV Horror, TV Mysteries'],
#        ...,
#        ['s8801', 'TV Show', 'Zindagi Gulzar Hai', ..., 'TV-PG',
#         '1 Season',
#         'International TV Shows, Romantic TV Shows, TV Dramas'],
#        ['s8784', 'TV Show', 'Yoko', ..., 'TV-Y', '1 Season', "Kids' TV"],
#        ['s8786', 'TV Show', 'YOM', ..., 'TV-Y7', '1 Season', "Kids' TV"]],
#       dtype=object)

# %%
# check the shape
nfx.shape
# Out:
# (8790, 10)

# %%
#  size
nfx.size
# Out:
# 87900

# %%
#  ndim
nfx.ndim
# Out:
# 2

# %%
# index
nfx.index
# Out:
# RangeIndex(start=0, stop=8790, step=1)

# %%
# is_unique
nfx.is_unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7632\2229237874.py in ?()
#       1 # is_unique
# ----> 2 nfx.is_unique
#
# c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'is_unique'

# %%
# Methods

# %%
#  top 5 row
nfx.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#  bottum 5 rows
nfx.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
# total use byte
nfx.memory_usage()
# Out:
# Index             132
# show_id         70320
# type            70320
# title           70320
# director        70320
# country         70320
# date_added      70320
# release_year    70320
# rating          70320
# duration        70320
# listed_in       70320
# dtype: int64

# %%
# Aggregate function

# %%
# Sum()
nfx.sum()
# Out:
# show_id         s1s3s6s14s8s9s10s939s13s940s941s942s852s471s73...
# type            MovieTV ShowTV ShowMovieMovieTV ShowMovieMovie...
# title           Dick Johnson Is DeadGanglandsMidnight MassConf...
# director        Kirsten JohnsonJulien LeclercqMike FlanaganBru...
# country         United StatesFranceUnited StatesBrazilUnited S...
# date_added      9/25/20219/24/20219/24/20219/22/20219/24/20219...
# release_year                                             17704670
# rating          PG-13TV-MATV-MATV-PGTV-MATV-14PG-13TV-Y7TV-MAT...
# duration        90 min1 Season1 Season91 min125 min9 Seasons10...
# listed_in       DocumentariesCrime TV Shows, International TV ...
# dtype: object

# %%
# min
nfx.min()
# Out:
# show_id                         s1
# type                         Movie
# title                       #Alive
# director               A. L. Vijay
# country                  Argentina
# date_added                1/1/2008
# release_year                  1925
# rating                           G
# duration                  1 Season
# listed_in       Action & Adventure
# dtype: object

# %%
# count
nfx.count()
# Out:
# show_id         8790
# type            8790
# title           8790
# director        8790
# country         8790
# date_added      8790
# release_year    8790
# rating          8790
# duration        8790
# listed_in       8790
# dtype: int64

# %%
# product
nfx.product
# Out:
# <bound method DataFrame.prod of      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
# ...

# %%
# nfx.argmin()

# %%
# nfx.argmax()

# %%
#  locate row

nfx.loc[[0]]
# Out:
#   show_id   type                 title         director        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
#
#   date_added  release_year rating duration      listed_in
# 0  9/25/2021          2020  PG-13   90 min  Documentaries

# %%
nfx.loc[[2,5,7]]
# Out:
#   show_id     type                            title         director  \
# 2      s6  TV Show                    Midnight Mass    Mike Flanagan
# 5      s9  TV Show    The Great British Baking Show  Andy Devonshire
# 7    s939    Movie  Motu Patlu in the Game of Zones      Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 2   United States  9/24/2021          2021  TV-MA   1 Season
# 5  United Kingdom  9/24/2021          2021  TV-14  9 Seasons
# 7           India   5/1/2021          2019  TV-Y7     87 min
#
#                                            listed_in
# 2                 TV Dramas, TV Horror, TV Mysteries
# 5                       British TV Shows, Reality TV
# 7  Children & Family Movies, Comedies, Music & Mu...

# %% [markdown]
# Set and Reset Index

# %%
nfx.set_index('show_id') # show_id column as a index
    #   parmanent change inplace =True
# Out:
#             type                             title         director  \
# show_id
# s1         Movie              Dick Johnson Is Dead  Kirsten Johnson
# s3       TV Show                         Ganglands  Julien Leclercq
# s6       TV Show                     Midnight Mass    Mike Flanagan
# s14        Movie  Confessions of an Invisible Girl    Bruno Garotti
# s8         Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# s8797    TV Show                        Yunus Emre        Not Given
# s8798    TV Show                         Zak Storm        Not Given
# s8801    TV Show                Zindagi Gulzar Hai        Not Given
# s8784    TV Show                              Yoko        Not Given
# s8786    TV Show                               YOM        Not Given
#
#                country  date_added  release_year rating   duration  \
# show_id
# ...

# %% [markdown]
# excess the single column

# %%
nfx.title
# Out:
# 0                   Dick Johnson Is Dead
# 1                              Ganglands
# 2                          Midnight Mass
# 3       Confessions of an Invisible Girl
# 4                                Sankofa
#                       ...
# 8785                          Yunus Emre
# 8786                           Zak Storm
# 8787                  Zindagi Gulzar Hai
# 8788                                Yoko
# 8789                                 YOM
# Name: title, Length: 8790, dtype: object

# %% [markdown]
# multiple column excess

# %%
nfx[['title','rating','release_year']]
# Out:
#                                  title rating  release_year
# 0                 Dick Johnson Is Dead  PG-13          2020
# 1                            Ganglands  TV-MA          2021
# 2                        Midnight Mass  TV-MA          2021
# 3     Confessions of an Invisible Girl  TV-PG          2021
# 4                              Sankofa  TV-MA          1993
# ...                                ...    ...           ...
# 8785                        Yunus Emre  TV-PG          2016
# 8786                         Zak Storm  TV-Y7          2016
# 8787                Zindagi Gulzar Hai  TV-PG          2012
# 8788                              Yoko   TV-Y          2016
# 8789                               YOM  TV-Y7          2016
#
# [8790 rows x 3 columns]

# %% [markdown]
# ReName the columns

# %%
nfx.rename(columns={'show_id':'ID','title':'Title'}) 

# chage the columns name but not parmanent change because i am not using (inplace=True).
# Out:
#          ID     type                             Title         director  \
# 0        s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        s3  TV Show                         Ganglands  Julien Leclercq
# 2        s6  TV Show                     Midnight Mass    Mike Flanagan
# 3       s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        s8    Movie                           Sankofa     Haile Gerima
# ...     ...      ...                               ...              ...
# 8785  s8797  TV Show                        Yunus Emre        Not Given
# 8786  s8798  TV Show                         Zak Storm        Not Given
# 8787  s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788  s8784  TV Show                              Yoko        Not Given
# 8789  s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# indexing

# %%
#  as a row wise indexing
nfx[0:2]
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...

# %%
#  as a columns wise indexing

nfx['title'][3]
# Out:
# 'Confessions of an Invisible Girl'

# %%
nfx['type'][1:5]
# Out:
# 1    TV Show
# 2    TV Show
# 3      Movie
# 4      Movie
# Name: type, dtype: object

# %%
nfx['listed_in'][4:11]
# Out:
# 4      Dramas, Independent Movies, International Movies
# 5                          British TV Shows, Reality TV
# 6                                      Comedies, Dramas
# 7     Children & Family Movies, Comedies, Music & Mu...
# 8                          Dramas, International Movies
# 9            Children & Family Movies, Music & Musicals
# 10                   Children & Family Movies, Comedies
# Name: listed_in, dtype: object

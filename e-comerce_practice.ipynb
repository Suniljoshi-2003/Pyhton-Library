# %%
import pandas as pd

# x = pd.read_csv("C:\\Users\\lenovo\\Desktop\\Downloads\\Data\\ecommerce_sales.csv")
# # UnicodeDecodeError

# # ‘Efbwbfhj//wefjb/wjfb/csv’,encoding=‘unicode_escape’

# x = pd.read_csv("C:\\Users\\lenovo\\Desktop\\Downloads\\Data\\ecommerce_sales.csv",encoding=‘unicode_escape’)

# %%
import pandas as pd

# Corrected code
data = pd.read_csv("C:\\Users\\lenovo\\Desktop\\Downloads\\Data\\ecommerce_sales.csv", encoding='unicode_escape')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#  
data.index.get_level_values("Country")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 #
# ----> 2 data.index.get_level_values("Country")
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:2102, in Index._get_level_values(self, level)
#    2066 def _get_level_values(self, level) -> Index:
#    2067     """
#    2068     Return an Index of values for requested level.
#    2069
#    (...)
#    2100     Index(['a', 'b', 'c'], dtype='object')
#    2101     """
# -> 2102     self._validate_index_level(level)
#    2103     return self
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:2012, in Index._validate_index_level(self, level)
#    2008         raise IndexError(
#    2009             f"Too many levels: Index has only 1 level, not {level + 1}"
#    2010         )
# ...

# %%
data.index.set_names(names=['Transaction Location','Transaction Date'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data.index.set_names(names=['Transaction Location','Transaction Date'],inplace=True)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:1909, in Index.set_names(self, names, level, inplace)
#    1906 else:
#    1907     idx = self._view()
# -> 1909 idx._set_names(names, level=level)
#    1910 if not inplace:
#    1911     return idx
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:1787, in Index._set_names(self, values, level)
#    1785     raise ValueError("Names must be a list-like")
#    1786 if len(values) != 1:
# -> 1787     raise ValueError(f"Length of new names must be 1, got {len(values)}")
#    1789 # GH 20527
#    1790 # All items in 'name' need to be hashable:
# ...

# %%
#  transpose --> column --> index
                # index --> column

# %%
raw_data = {'Bank Client ID': ['1', '2', '3', '4', '5'],
            'First Name': ['Nancy', 'Alex', 'Shep', 'Max', 'Allen'], 
            'Last Name': ['Rob', 'Ali', 'George', 'Mitch', 'Steve']}

bank1_df = pd.DataFrame(raw_data, columns = ['Bank Client ID', 'First Name', 'Last Name'])
bank1_df
# Out:
#   Bank Client ID First Name Last Name
# 0              1      Nancy       Rob
# 1              2       Alex       Ali
# 2              3       Shep    George
# 3              4        Max     Mitch
# 4              5      Allen     Steve

# %%
raw_data = {
        'Bank Client ID': ['6', '7', '8', '9', '10'],
        'First Name': ['Bill', 'Dina', 'Sarah', 'Heather', 'Holly'], 
        'Last Name': ['Christian', 'Mo', 'Steve', 'Bob', 'Michelle']}
bank2_df = pd.DataFrame(raw_data, columns = ['Bank Client ID', 'First Name', 'Last Name'])
bank2_df
# Out:
#   Bank Client ID First Name  Last Name
# 0              6       Bill  Christian
# 1              7       Dina         Mo
# 2              8      Sarah      Steve
# 3              9    Heather        Bob
# 4             10      Holly   Michelle

# %%
# bank_all_df = pd.concat([bank1_df,bank2_df])

# %%
# bank_all_df
#  index 0123401234   #ingnore_index=True
# Out:
#   Bank Client ID First Name  Last Name
# 0              1      Nancy        Rob
# 1              2       Alex        Ali
# 2              3       Shep     George
# 3              4        Max      Mitch
# 4              5      Allen      Steve
# 0              6       Bill  Christian
# 1              7       Dina         Mo
# 2              8      Sarah      Steve
# 3              9    Heather        Bob
# 4             10      Holly   Michelle

# %%
bank_all_df = pd.concat([bank1_df,bank2_df],ignore_index=True)

bank_all_df
# Out:
#   Bank Client ID First Name  Last Name
# 0              1      Nancy        Rob
# 1              2       Alex        Ali
# 2              3       Shep     George
# 3              4        Max      Mitch
# 4              5      Allen      Steve
# 5              6       Bill  Christian
# 6              7       Dina         Mo
# 7              8      Sarah      Steve
# 8              9    Heather        Bob
# 9             10      Holly   Michelle

# %%
# note - update
# append not working

# %% [markdown]
# """# set
# # reset
# # selecting the column-- . []
# # deleting the column --> del, drop, pop
# # add --> = , insert
# # fillna --> bfill, ffill
# # drop null values --> any , axix , all
# # chack null values --> isna, isnull
# # rename
# # multiindexing
# # groupby
# # swaplv
# # fetch the index
# # changing the name of index
# # concat
# # info
# # methods
# # attributes
# # spcl values
# """

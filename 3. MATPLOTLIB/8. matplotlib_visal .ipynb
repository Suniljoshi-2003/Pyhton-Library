# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import datetime

# %%
abc= pd.read_csv(r"C:\Users\lenovo\Desktop\Downloads\Data\crypto_daily_prices.csv")

# %%
abc
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
abc.plot(x='Date',y='BTC-USD Price')
# Out:
# <Axes: xlabel='Date'>

# %%
abc.plot(x='Date',y='BTC-USD Price',label='Bitcoin Price', linewidth = 1.5, figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
abc.plot(x='Date', y='BTC-USD Price',
         label='Bitcoin Price',
         linewidth =3, figsize=(14,6))
plt.ylabel ('Price[$]')
plt.xlabel ('Date')
plt.title ('My First Data Visualization')
plt.legend(loc ='upper left')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible: 'bool | None' = None, which: "Literal['major', 'minor', 'both']" = 'major', axis: "Literal['both', 'x', 'y']" = 'both', **kwargs) -> 'None'>

# %%
abc.plot(x='Date', y='BTC-USD Price',
         label='Bitcoin Price',
         linewidth =3, figsize=(14,6))
         
plt.ylabel ('Price[$]',color='Black',fontsize=11,fontname='ALGERIAN')
plt.xlabel ('Date', fontsize = 17 , fontname='ALGERIAN')
plt.title ('My First Data Visualization',color='Red',fontsize=17, fontname='Snap ITC')
plt.legend(loc ='upper left')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible: 'bool | None' = None, which: "Literal['major', 'minor', 'both']" = 'major', axis: "Literal['both', 'x', 'y']" = 'both', **kwargs) -> 'None'>

# %%
plt.plot(x='Date',y='ETH-USD Price',label='Bitcoin',linewidth=2.5,figsize=(10,5),color='b')
plt.ylabel('Price[$]',color='Black',fontsize=11,fontname="ALGERIAN")
plt.xlabel('Date',fontsize=17,fontname='ALGERIAN')
plt.title('My First Data Visualization Exercise',color='Black',fontsize=17,fontname='Snap ITC')
plt.legend(loc="upper left")
plt.grid(linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.plot(x='Date',y='ETH-USD Price',label='Bitcoin',linewidth=2.5,figsize=(10,5),color='b')
#       2 plt.ylabel('Price[$]',color='Black',fontsize=11,fontname="ALGERIAN")
#       3 plt.xlabel('Date',fontsize=17,fontname='ALGERIAN')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# ...

# %%
abc.plot(x='Date',y=["BTC-USD Price","ETH-USD Price","LTC-USD Price"],linewidth=2,figsize=(15,5))
plt.ylabel("Price")
plt.xlabel('Date')
plt.title("Crypto Prices")
plt.grid()

# %%
# Subplot

abc.plot(x='Date', title='rypto Prices', subplots=True,grid=True,figsize=(15,25))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
# scatter plot
abc.plot.scatter(x='BTC-USD Price',y='ETH-USD Price', grid =True, figsize=(10,7))
# Out:
# <Axes: xlabel='BTC-USD Price', ylabel='ETH-USD Price'>

# %%
abc.plot(x='Date',title='rypto Prices',subplots=True,grid=True,figsize=(15,25))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
my_dict={'ravi%':[20,35,15,17,13]}

# %%
a=pd.DataFrame(data=my_dict,index=['BTC','ETH','LTC',"XRP",'ADA'])
a
# Out:
#      ravi%
# BTC     20
# ETH     35
# LTC     15
# XRP     17
# ADA     13

# %%
a.plot.pie(y="ravi%", figsize=(5,5),autopct='% .2f %%',pctdistance=0.5)
plt.title('CRYPTO PORTFOLIO PIE CHART')
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %%
explode=(0.1,0,0.1,0.1)
a.plot.pie(y="ravi%", figsize=(5,5),autopct='% .2f %%',pctdistance=0.5)
plt.title('CRYPTO PORTFOLIO PIE CHART')
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %% [markdown]
# # HOISTOGRAM

# %%
abc['BTC-USD Price'].plot.hist(bins=20,alpha= 1,figsize= (12,6))
plt.grid()
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# # BARCHAT

# %%
labels=['a','b','c']
values=[1,4,10]
bars=plt.bar(labels,values)

# %%
labels=['a','b','c']
values=[1,4,10]
bars=plt.bar(labels,values)

patterns = ['/','o','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

# %%
import seaborn as sns

import pandas as pd

# %%
cancer_df = pd.read_csv(r"C:\Users\lenovo\Desktop\Downloads\Data\cancer.csv")

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...
